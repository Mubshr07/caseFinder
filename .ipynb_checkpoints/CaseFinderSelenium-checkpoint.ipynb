# %%
import requests
from bs4 import BeautifulSoup
import datetime
import time
import os
from selenium import  webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions
from selenium.common.exceptions import TimeoutException

import pandas, numpy

mainWebSiteURL = "https://dsjlahore.punjab.gov.pk"

listofJudges = []
listofJudgesNames = []


print("this is main method:")
print(" url is: {}".format(mainWebSiteURL))


#driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver = webdriver.Chrome()
driver.get(mainWebSiteURL)
print(driver.title)

courtID = (driver.find_element(By.ID, "court_id_clist"))
print("court Combo:: {}".format(courtID.text[0:300]))

print("\n\n---------------------------------------------\n\n") 


ddelement = Select(driver.find_element(By.NAME, "district_id"))
#ddelement= Select(driver.find_element_by_css_selector('container'))

print(ddelement.is_multiple)
#for option in ddelement.options:
#    print(option.text)
# select by visible text
ddelement.select_by_value('28')
# Out:
# this is main method:
#  url is: https://dsjlahore.punjab.gov.pk
# Case Management System | District Judiciary Punjab
# court Combo:: Select Court Name
# Mr. Muhammad Tanveer Akbar, DSJ
# Ch. Ghulam Rasool, AD&SJ
# Ch. Muhammad Asif, AD&SJ
# Hafiz Husnain Azhar Shah, AD&SJ
# Malik Noor Khan, AD&SJ
# Mian Masood Hussain, AD&SJ
# Mian Mudassar Umar Bodla, AD&SJ
# Mian Shahid Javed, AD&SJ
# Mr. Abdul Ghaffar, AD&SJ
# Mr. Abdul Ghafoor, AD&SJ
# Mr. Abdul Q
#
#
# ---------------------------------------------
#
#
# None

# %%
courtID = (driver.find_element(By.ID, "court_id_clist"))
#print("court Combo:: {}".format(courtID.text))
selec = Select(courtID)

print("court Combo:: {} -> {}".format(selec.options[3].text, selec.options[3].get_attribute("value")))

print("Value -> Text")
for option in selec.options:
    #print("{} -> {}".format(option.get_attribute("value"), option.text))
    listofJudges.append(option.get_attribute('value'))
    listofJudgesNames.append(option.text)

print(" Total Judges : {} -> nameList: {}".format(len(listofJudges), len(listofJudgesNames)))
while("" in listofJudges) :
    listofJudges.remove("")
while("" in listofJudgesNames) :
    listofJudgesNames.remove("")
   

print(" Total Judges : {} -> nameList: {}".format(len(listofJudges), len(listofJudgesNames)))
print("Judges ID : {}".format(listofJudges)) 




print(driver.title)
print(driver.current_url)
driver.close()
driver.quit()
# Out:
# court Combo:: Mr. Intikhab Alam, AD&SJ -> 1304
# Value -> Text
#  Total Judges : 51 -> nameList: 51
#  Total Judges : 50 -> nameList: 51
# Judges ID : ['1301', '1303', '1304', '1706', '1302', '580', '1736', '1305', '1306', '1308', '1307', '1317', '1592', '1316', '1319', '1315', '1318', '1311', '1314', '1313', '1312', '665', '663', '664', '1325', '1322', '1324', '1321', '1323', '1320', '1327', '1707', '1326', '1735', '1331', '1330', '1332', '1335', '1334', '1333', '1329', '1337', '1737', '1824', '1344', '1340', '1343', '1342', '1341', '1339']
# Case Management System | District Judiciary Punjab
# https://dsjlahore.punjab.gov.pk/

# %%
myNames = []  
#myNames.append("مبشر") 
myNames.append("مبشر اقبال")
myNames.append("مبشراقبال")
#myNames.append("ظفر")
#myNames.append("ظفر اقبال")
#myNames.append("خدا بخش")
 
judgesIndex = 0
start = 1
end = 32
current = start
headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:108.0) Gecko/20100101 Firefox/108.0"}


while(judgesIndex<len(listofJudges)):
    print("judges index:{}/{} -> ID: {} -> Name: {}".format(judgesIndex, len(listofJudges), listofJudges[judgesIndex], listofJudgesNames[judgesIndex]))
    while(current < end):
        url = "https://dsjlahore.punjab.gov.pk/causelist?clist_cid={}&clist_dated={:02d}-06-2023&district=28".format(listofJudges[judgesIndex], current)
        #print(url) 
        try:
            response = requests.get(url, headers)
            doc = BeautifulSoup(response.text, 'lxml') 
            for text in myNames:
                findedInfo = doc.find_all(lambda tag: tag.name == "tr" and text in tag.text)
                if(len(findedInfo)>0):
                    for ele in findedInfo:
                        achorTags = ele.find_all(href=True)
                        textElement = ele.find_all(lambda tag: tag.name == "td" and text in tag.text)[0].text
                        for a in achorTags:
                            print("Check the URL: {} => for:: {}".format(a["href"], textElement))
                            #print("############################")
                            #print("\n\n ")
                    #print("***********************")
                    #print("\n\n")               
        
        except Exception as e:
            # Code to handle any other exceptions
            print("Error:", str(e))
            print("URL:", url)
            print("\n\n ")
    
        current += 1
                  
        #print("\n---------------------------------------------------")
        #print("\n---------------------------------------------------")
    
    current = start
    judgesIndex += 1
    

print("\n##################################################")
print("             END                   ")
print("\n##################################################")
# Out:
# judges index:0/50 -> ID: 1301 -> Name: Select Court Name
# judges index:1/50 -> ID: 1303 -> Name: Mr. Muhammad Ashiq, DSJ
# judges index:2/50 -> ID: 1304 -> Name: Mr. Amjad Ali Bajwa, AD&SJ
# judges index:3/50 -> ID: 1706 -> Name: Mr. Intikhab Alam, AD&SJ
# judges index:4/50 -> ID: 1302 -> Name: Mr. Khaleel Ahmad, AD&SJ
# judges index:5/50 -> ID: 580 -> Name: Mr. Mubbashar Nadeem Khan, AD&SJ
# judges index:6/50 -> ID: 1736 -> Name: Mr. Muhammad Yasar Hayat, AD&SJ
# Check the URL: https://dsjlahore.punjab.gov.pk/casedetail/97103421301931821ecb0f305b2 => for::
#                             مبشر اقبال  بنام  فاطمہ شوکت وغیرہ
#
#
# Check the URL: https://dsjlahore.punjab.gov.pk/casedetail/97103421301931821ecb0f305b2 => for::
#                             مبشر اقبال  بنام  فاطمہ شوکت وغیرہ
#
#
# Check the URL: https://dsjlahore.punjab.gov.pk/casedetail/97103421301931821ecb0f305b2 => for::
#                             مبشر اقبال  بنام  فاطمہ شوکت وغیرہ
#
#
# Check the URL: https://dsjlahore.punjab.gov.pk/casedetail/97103421301931821ecb0f305b2 => for::
#                             مبشر اقبال  بنام  فاطمہ شوکت وغیرہ
#
#
# Check the URL: https://dsjlahore.punjab.gov.pk/casedetail/97103421301931821ecb0f305b2 => for::
#                             مبشر اقبال  بنام  فاطمہ شوکت وغیرہ
#
#
# judges index:7/50 -> ID: 1305 -> Name: Mr. Riaz Ahmad, AD&SJ
# judges index:8/50 -> ID: 1306 -> Name: Mr. Zulfiqar Ali, AD&SJ
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error: HTTPSConnectionPool(host='dsjlahore.punjab.gov.pk', port=443): Max retries exceeded with url: /causelist?clist_cid=1306&clist_dated=06-06-2023&district=28&User-Agent=Mozilla%2F5.0+%28X11%3B+Ubuntu%3B+Linux+x86_64%3B+rv%3A108.0%29+Gecko%2F20100101+Firefox%2F108.0 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:997)')))
# judges index:9/50 -> ID: 1308 -> Name: Mr. Muhammad Jawad Alam Qureshi, SCJ (Civil Division)
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# judges index:10/50 -> ID: 1307 -> Name: Mr. Ahmad Khan Chatha, SCJ (Family Division)

# %%
 
judgesIndex = 0
start = 1
end = 32
current = start
headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:108.0) Gecko/20100101 Firefox/108.0"}
startMonth = 3

endMonth = int(datetime.datetime.now().strftime("%m")) #datetime.date.month #now().month

print("{} -> {}".format(startMonth, endMonth))


while (startMonth <= endMonth):

    while(judgesIndex<len(listofJudges)):
        print("judges id:{}".format(listofJudges[judgesIndex]))
        while(current < end):
            url = "https://dsjlahore.punjab.gov.pk/causelist?clist_cid={}&clist_dated={:02d}-{:02d}-2023&district=28".format(listofJudges[judgesIndex], current, startMonth)
            print(url) 
            #print("############################")
            #print("\n\n ")
            current += 1
        
        #print("***********************")
        print("\n\n")               
                 
        print("\n---------------------------------------------------")
        #print("\n---------------------------------------------------")
    
        current = start
        judgesIndex += 1
    
    print("\n---------------------------------------------------")
    print("\n/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*/*")
    print("\n---------------------------------------------------")
        

print("\n##################################################")
print("             END                   ")
print("\n##################################################")
